# %% [markdown]
# # First commit

# %% [markdown]
# ## Project Planner
#
# ### 1. Data
#
# Use real world data set: finance data?
#
# ### 2. Importing
#
# csv/txt/APIs
# yFinance, FX rates, Stock (AAPL etc), bitcoin
#
# ### 3. Pandas Dataframe
#
# Sorting/Indexing/Grouping
# Duplicats and NAs handling
# Merging data (Merge)
#
# ### 4. Conditional Statements
#
# Looping, groupby
# Numpy
# custom functions, dict/list: return monthly averages (etc) as lists
#
# ### 5. 2 charts

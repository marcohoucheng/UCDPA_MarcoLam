# %%
# %pip install yfinance --upgrade --no-cache-dir

# %%
# Load packages
import yfinance as yf
import numpy as np
import pandas as pd

# %%
ex_rates = pd.read_csv('euro-daily-hist_1999_2022.csv')

# %%
#ex_rates = ex_rates.set_index(r'Period\Unit:')

# %%
list(ex_rates.columns)

# %%
USDEUR = ex_rates[['Period\\Unit:', '[US dollar ]']]
USDEUR = USDEUR.rename(columns = {'Period\\Unit:':'Date', '[US dollar ]':'USDEUR'})

# %%
USDEUR['Date'] = pd.to_datetime(USDEUR['Date'], infer_datetime_format=True)
USDEUR = USDEUR.set_index('Date')

# %%
USDEUR_2021 = USDEUR.loc['2021-12-31':'2021-01-01'].astype('float64')

# %%
df = yf.download(  # or pdr.get_data_yahoo(...
        # tickers list or string as well
        tickers = "AAPL BTC-USD",
        # tickers = "AAPL MSFT",

        # use "period" instead of start/end
        # valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
        # (optional, default is '1mo')
        #period = "ytd",
        start="2021-01-01", end="2021-12-31",

        # fetch data by interval (including intraday if period < 60 days)
        # valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
        # (optional, default is '1d')
        interval = "1d",

        # group by ticker (to access via data['SPY'])
        # (optional, default is 'column')
        #group_by = 'ticker',

        # adjust all OHLC automatically
        # (optional, default is False)
        auto_adjust = True,

        # download pre/post regular market hours data
        # (optional, default is False)
        prepost = True,

        # use threads for mass downloading? (True/False/Integer)
        # (optional, default is True)
        threads = True,

        # proxy URL scheme use use when downloading?
        # (optional, default is None)
        proxy = None
    )

df = df[["Open"]]
df.columns = ['AAPL', 'BTCUSD']
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
master_USD = pd.concat([USDEUR_2021, df], axis=1)

# %%
master_USD = pd.merge(USDEUR_2021, df, left_index=True, right_index=True)
# Remove NAs
master_USD = master_USD.dropna()

# %%
master_EUR = pd.concat([pd.DataFrame({'EUR':master_USD.AAPL / master_USD.USDEUR, 'Ticker':"AAPL"}),
                        pd.DataFrame({'EUR':master_USD.BTCUSD / master_USD.USDEUR, 'Ticker':"BTCEUR"})])
#master_EUR = pd.DataFrame({'AAPL':master_USD.AAPL / master_USD.USDEUR, 'BTCEUR':master_USD.BTCUSD / master_USD.USDEUR})

# %%
master_EUR['Month'] = pd.DatetimeIndex(master_EUR.index).month

# %%
# If you wanna see the data by date
master_EUR.sort_index(ascending = True)
# Out:
#                      EUR  Ticker  Month
# Date
# 2021-01-04    104.314398    AAPL      1
# 2021-01-04  26001.881964  BTCEUR      1
# 2021-01-05  27701.434021  BTCEUR      1
# 2021-01-05    105.819286    AAPL      1
# 2021-01-06    101.701938    AAPL      1
# ...                  ...     ...    ...
# 2021-12-28  41998.813405  BTCEUR     12
# 2021-12-29    158.266758    AAPL     12
# 2021-12-29  41090.605094  BTCEUR     12
# 2021-12-30  41625.308805  BTCEUR     12
# 2021-12-30    156.795609    AAPL     12
#
# [500 rows x 3 columns]

# %%
# If you wanna see the data by ticker
master_EUR_sorted = master_EUR.sort_values(by = ['Ticker', 'Date'], ascending = [True, True])

# %%
master_EUR_agg = master_EUR.groupby(['Ticker', 'Month']).agg(['min','mean','max','std'])

# %%
master_EUR_agg.columns = ['Min','Mean','Max','STD']
master_EUR_agg
# Out:
#                        Min          Mean           Max          STD
# Ticker Month
# AAPL   1        101.701938    108.303228    116.851965     4.706618
#        2         98.240228    107.917993    113.516499     4.694708
#        3         97.339282    101.665637    105.242342     1.811877
#        4        103.945070    109.461582    112.171879     2.001795
#        5        100.736566    103.787738    109.235788     2.179377
#        6        100.794456    107.305530    114.592710     4.417169
#        7        114.852073    122.101321    125.683902     2.661928
#        8        121.734275    125.317030    129.207924     1.931533
#        9        121.009802    125.503300    131.562669     3.215418
#        10       119.076018    124.940376    131.053729     3.122463
#        11       127.630252    134.693334    145.073901     6.187704
#        12       142.942987    152.970021    158.978358     4.970871
# BTCEUR 1      25121.798642  28714.479734  33304.170918  2355.372207
#        2      27753.372874  37826.075738  46040.145657  5259.573325
#        3      40221.972299  45927.242820  50250.603012  3218.321046
#        4      42345.145321  47827.350381  53382.193200  3332.843014
#        5      29400.103335  38535.785558  47833.409257  7016.519922
#        6      26475.129119  29842.399831  33371.547350  1982.259845
#        7      25314.095674  29073.296555  35518.919246  2815.678023
#        8      32101.792569  38568.572144  42282.086054  2972.907725
#        9      34668.321504  38484.846258  42137.276786  2199.850131
#        10     41480.121902  50139.052486  56777.799137  4151.797971
#        11     47444.660017  53171.997845  58352.904504  2899.812524
#        12     40778.591819  43700.082911  50583.196151  2764.295417

# %%
master_EUR_sorted.groupby(['Ticker']).count()
# Out:
#         EUR  Month
# Ticker
# AAPL    250    250
# BTCEUR  250    250

# %%
from datetime import datetime
AAPL_EUR = []
AAPL_EUR_Date = []
for lab, row in master_EUR_sorted.iterrows():
    AAPL_EUR.append(row["EUR"])
    AAPL_EUR_Date.append(lab.to_pydatetime().strftime("%d/%m/%Y"))

BTCEUR = []
BTCEUR_Date = []
for lab, row in master_EUR_sorted.iterrows():
    BTCEUR.append(row["EUR"])
    BTCEUR_Date.append(lab.to_pydatetime().strftime("%d/%m/%Y"))

# %%
AAPL_EUR_Dict = dict(zip(AAPL_EUR_Date, AAPL_EUR))
BTCEUR_Dict = dict(zip(BTCEUR_Date, BTCEUR))

# %%
AAPL_EUR = np.zeros(shape=(master_EUR_sorted.groupby(['Ticker']).count().loc[['AAPL'],['EUR']].squeeze(), 2))
BTCEUR = np.zeros(shape=(master_EUR_sorted.groupby(['Ticker']).count().loc[['BTCEUR'],['EUR']].squeeze(), 2))

# %%
i = 0
j = 0
for lab, row in master_EUR_sorted.iterrows():
    if row["Ticker"] == "AAPL":
        AAPL_EUR[i,0] = lab.to_numpy()
        AAPL_EUR[i,1] = row["EUR"]
        i = i + 1
    else:
        BTCEUR[j,0] = lab.to_numpy()
        BTCEUR[j,1] = row["EUR"]
        j = j + 1

# %%
np.round(AAPL_EUR, 0)

# %%
master_EUR_agg
# Out:
#                        Min          Mean           Max          STD
# Ticker Month
# AAPL   1        101.701938    108.303228    116.851965     4.706618
#        2         98.240228    107.917993    113.516499     4.694708
#        3         97.339282    101.665637    105.242342     1.811877
#        4        103.945070    109.461582    112.171879     2.001795
#        5        100.736566    103.787738    109.235788     2.179377
#        6        100.794456    107.305530    114.592710     4.417169
#        7        114.852073    122.101321    125.683902     2.661928
#        8        121.734275    125.317030    129.207924     1.931533
#        9        121.009802    125.503300    131.562669     3.215418
#        10       119.076018    124.940376    131.053729     3.122463
#        11       127.630252    134.693334    145.073901     6.187704
#        12       142.942987    152.970021    158.978358     4.970871
# BTCEUR 1      25121.798642  28714.479734  33304.170918  2355.372207
#        2      27753.372874  37826.075738  46040.145657  5259.573325
#        3      40221.972299  45927.242820  50250.603012  3218.321046
#        4      42345.145321  47827.350381  53382.193200  3332.843014
#        5      29400.103335  38535.785558  47833.409257  7016.519922
#        6      26475.129119  29842.399831  33371.547350  1982.259845
#        7      25314.095674  29073.296555  35518.919246  2815.678023
#        8      32101.792569  38568.572144  42282.086054  2972.907725
#        9      34668.321504  38484.846258  42137.276786  2199.850131
#        10     41480.121902  50139.052486  56777.799137  4151.797971
#        11     47444.660017  53171.997845  58352.904504  2899.812524
#        12     40778.591819  43700.082911  50583.196151  2764.295417

# %%
import calendar
for lab, row in master_EUR_agg.iterrows():
    master_EUR_agg.loc[lab, "Ticker"] = lab[0]
    master_EUR_agg.loc[lab, "Month"] = calendar.month_name[lab[1]]
master_EUR_agg
# Out:
#                        Min          Mean           Max          STD  Ticker  \
# Ticker Month
# AAPL   1        101.701938    108.303228    116.851965     4.706618    AAPL
#        2         98.240228    107.917993    113.516499     4.694708    AAPL
#        3         97.339282    101.665637    105.242342     1.811877    AAPL
#        4        103.945070    109.461582    112.171879     2.001795    AAPL
#        5        100.736566    103.787738    109.235788     2.179377    AAPL
#        6        100.794456    107.305530    114.592710     4.417169    AAPL
#        7        114.852073    122.101321    125.683902     2.661928    AAPL
#        8        121.734275    125.317030    129.207924     1.931533    AAPL
#        9        121.009802    125.503300    131.562669     3.215418    AAPL
#        10       119.076018    124.940376    131.053729     3.122463    AAPL
#        11       127.630252    134.693334    145.073901     6.187704    AAPL
#        12       142.942987    152.970021    158.978358     4.970871    AAPL
# BTCEUR 1      25121.798642  28714.479734  33304.170918  2355.372207  BTCEUR
#        2      27753.372874  37826.075738  46040.145657  5259.573325  BTCEUR
#        3      40221.972299  45927.242820  50250.603012  3218.321046  BTCEUR
#        4      42345.145321  47827.350381  53382.193200  3332.843014  BTCEUR
#        5      29400.103335  38535.785558  47833.409257  7016.519922  BTCEUR
#        6      26475.129119  29842.399831  33371.547350  1982.259845  BTCEUR
#        7      25314.095674  29073.296555  35518.919246  2815.678023  BTCEUR
#        8      32101.792569  38568.572144  42282.086054  2972.907725  BTCEUR
#        9      34668.321504  38484.846258  42137.276786  2199.850131  BTCEUR
#        10     41480.121902  50139.052486  56777.799137  4151.797971  BTCEUR
#        11     47444.660017  53171.997845  58352.904504  2899.812524  BTCEUR
#        12     40778.591819  43700.082911  50583.196151  2764.295417  BTCEUR
#
#                   Month
# Ticker Month
# AAPL   1        January
#        2       February
#        3          March
#        4          April
#        5            May
#        6           June
#        7           July
#        8         August
#        9      September
#        10       October
#        11      November
#        12      December
# BTCEUR 1        January
#        2       February
#        3          March
#        4          April
#        5            May
#        6           June
#        7           July
#        8         August
#        9      September
#        10       October
#        11      November
#        12      December

# %%
import plotly.express as px
fig = px.scatter(master_EUR_agg, x='Mean', y='STD', color="Ticker", hover_data=['Month'])
fig.show()
# Out:
# <div>                            <div id="69bd13dd-ae3f-46ab-89e4-2a029c992013" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("69bd13dd-ae3f-46ab-89e4-2a029c992013")) {                    Plotly.newPlot(                        "69bd13dd-ae3f-46ab-89e4-2a029c992013",                        [{"customdata":[["January"],["February"],["March"],["April"],["May"],["June"],["July"],["August"],["September"],["October"],["November"],["December"]],"hovertemplate":"Ticker=AAPL<br>Mean=%{x}<br>STD=%{y}<br>Month=%{customdata[0]}<extra></extra>","legendgroup":"AAPL","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"AAPL","orientation":"v","showlegend":true,"x":[108.30322779099781,107.91799332197948,101.66563712806544,109.461581529754,103.78773808963487,107.30553037723631,122.10132116129377,125.31703009558547,125.50329982869442,124.9403764361336,134.69333425296603,152.97002110112987],"xaxis":"x","y":[4.706617616502027,4.6947082448270505,1.8118771342963926,2.001794898218546,2.1793773008640946,4.417168643813091,2.6619281162428887,1.9315325948812307,3.2154184280426104,3.1224627695442755,6.18770373661782,4.970870936577521],"yaxis":"y","type":"scatter"},{"customdata":[["January"],["February"],["March"],["April"],["May"],["June"],["July"],["August"],["September"],["October"],["November"],["December"]],"hovertemplate":"Ticker=BTCEUR<br>Mean=%{x}<br>STD=%{y}<br>Month=%{customdata[0]}<extra></extra>","legendgroup":"BTCEUR","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"BTCEUR","orientation":"v","showlegend":true,"x":[28714.479734168155,37826.07573757295,45927.24281992139,47827.35038144765,38535.78555754559,29842.39983100167,29073.296554947232,38568.57214434863,38484.846257886966,50139.05248590898,53171.997844981626,43700.08291052574],"xaxis":"x","y":[2355.3722067390718,5259.573325041659,3218.3210455554945,3332.8430144807016,7016.519921674624,1982.259844776648,2815.678023045681,2972.9077254873314,2199.850131236858,4151.797970684402,2899.812523756267,2764.2954167168946],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[ ...

# %%
fig = px.scatter(master_EUR_agg[master_EUR_agg['Ticker'] == "AAPL"], x='Mean', y='STD', color="STD", hover_data=['Month'], title = "AAPL")
fig.show()
# Out:
# <div>                            <div id="d7b18bdd-c747-4300-9d28-cd54959480ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58872143-41a0-4a75-a586-5b131c4d09ac")) {                    Plotly.newPlot(                        "58872143-41a0-4a75-a586-5b131c4d09ac",                        [{"alignmentgroup":"True","hovertemplate":"Month=%{x}<br>Mean=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["January","February","March","April","May","June","July","August","September","October","November","December"],"xaxis":"x","y":[108.30322779099781,107.91799332197948,101.66563712806544,109.461581529754,103.78773808963487,107.30553037723631,122.10132116129377,125.31703009558547,125.50329982869442,124.9403764361336,134.69333425296603,152.97002110112987],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""} ...

# %%
df = yf.download(  # or pdr.get_data_yahoo(...
        # tickers list or string as well
        tickers = "AAPL",
        # tickers = "AAPL MSFT",

        # use "period" instead of start/end
        # valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
        # (optional, default is '1mo')
        #period = "ytd",
        start="2021-01-01", end="2021-12-31",

        # fetch data by interval (including intraday if period < 60 days)
        # valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
        # (optional, default is '1d')
        interval = "1d",

        # group by ticker (to access via data['SPY'])
        # (optional, default is 'column')
        #group_by = 'ticker',

        # adjust all OHLC automatically
        # (optional, default is False)
        auto_adjust = True,

        # download pre/post regular market hours data
        # (optional, default is False)
        prepost = True,

        # use threads for mass downloading? (True/False/Integer)
        # (optional, default is True)
        threads = True,

        # proxy URL scheme use use when downloading?
        # (optional, default is None)
        proxy = None
    )
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close     Volume
# Date
# 2021-01-04  132.338619  132.427820  125.638430  128.264984  143301900
# 2021-01-05  127.749592  130.574382  127.293656  129.850830   97664900
# 2021-01-06  126.589944  129.890482  125.261796  125.479851  155088000
# 2021-01-07  127.224265  130.465336  126.728689  129.761612  109578200
# 2021-01-08  131.258280  131.456523  129.077749  130.881653  105158200
# ...                ...         ...         ...         ...        ...
# 2021-12-23  175.368578  176.365841  174.790164  175.797394   68356600
# 2021-12-27  176.605184  179.926069  176.585249  179.836319   74919600
# 2021-12-28  179.666792  180.833588  178.041250  178.799164   79144300
# 2021-12-29  178.839050  180.135494  177.652305  178.888916   62348900
# 2021-12-30  178.978670  180.075665  177.602443  177.712143   59773000
#
# [251 rows x 5 columns]

# %%
import plotly.graph_objects as go
fig = go.Figure(data=[go.Candlestick(x=df.index,
                open=df['Open'],
                high=df['High'],
                low=df['Low'],
                close=df['Close'])])

fig.show()
# Out:
# <div>                            <div id="535c1fba-1fa6-42aa-bfc7-8c607638ad8a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("535c1fba-1fa6-42aa-bfc7-8c607638ad8a")) {                    Plotly.newPlot(                        "535c1fba-1fa6-42aa-bfc7-8c607638ad8a",                        [{"close":[128.26498413085938,129.850830078125,125.47985076904297,129.76161193847656,130.88165283203125,127.83879852294922,127.660400390625,129.7318878173828,127.76942443847656,126.01507568359375,126.69896697998047,130.86181640625,135.6589813232422,137.83953857421875,141.65542602539062,141.89332580566406,140.8030548095703,135.8770294189453,130.79241943359375,132.953125,133.79562377929688,132.75491333007812,136.1743621826172,135.7525177001953,135.90139770507812,135.00802612304688,134.39260864257812,134.13450622558594,134.37274169921875,132.2088165283203,129.87611389160156,128.75445556640625,128.9132843017